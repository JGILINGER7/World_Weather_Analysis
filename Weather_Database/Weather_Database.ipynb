# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#create an empty list to hold data
# Create a list for holding the cities.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | beloha
# Processing Record 4 of Set 1 | heinsberg
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 1 | tonj
# Processing Record 8 of Set 1 | kloulklubed
# Processing Record 9 of Set 1 | plettenberg bay
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | ihosy
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | bulungu
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | pangai
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ostrovnoy
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | kapuskasing
# Processing Record 26 of Set 1 | moshenskoye
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | sassandra
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | half moon bay
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | kirakira
# Processing Record 35 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 1 | ust-nera
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | beausejour
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | bandar-e lengeh
# Processing Record 45 of Set 1 | sinnamary
# Processing Record 46 of Set 1 | rupert
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | whyalla
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | havoysund
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | cam ranh
# Processing Record 7 of Set 2 | nador
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | churachandpur
# Processing Record 10 of Set 2 | zonguldak
# Processing Record 11 of Set 2 | pacific grove
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | songwa
# Processing Record 14 of Set 2 | asau
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | tanshui
# City not found. Skipping...
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | swan river
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | sarab
# Processing Record 21 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | vao
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | pochutla
# Processing Record 29 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 2 | la ronge
# Processing Record 31 of Set 2 | egvekinot
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | muriti
# Processing Record 34 of Set 2 | vallenar
# Processing Record 35 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 2 | spencer
# Processing Record 37 of Set 2 | palauig
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | zalari
# Processing Record 40 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | praia da vitoria
# Processing Record 43 of Set 2 | noumea
# Processing Record 44 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | jalingo
# Processing Record 48 of Set 2 | popondetta
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | romans-sur-isere
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | sao gabriel da cachoeira
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | yulara
# Processing Record 8 of Set 3 | upernavik
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | matagami
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | cervo
# Processing Record 13 of Set 3 | hundested
# Processing Record 14 of Set 3 | padang
# Processing Record 15 of Set 3 | mutsu
# Processing Record 16 of Set 3 | kedungwaru
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | vangaindrano
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | kidal
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | moose factory
# Processing Record 24 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 3 | moree
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | ziyamet
# City not found. Skipping...
# Processing Record 29 of Set 3 | nushki
# Processing Record 30 of Set 3 | mokhsogollokh
# Processing Record 31 of Set 3 | gairo
# Processing Record 32 of Set 3 | san ramon de la nueva oran
# Processing Record 33 of Set 3 | chenzhou
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | salalah
# Processing Record 37 of Set 3 | cururupu
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | yerofey pavlovich
# Processing Record 43 of Set 3 | atambua
# Processing Record 44 of Set 3 | derzhavinsk
# Processing Record 45 of Set 3 | salina cruz
# Processing Record 46 of Set 3 | kieta
# Processing Record 47 of Set 3 | guerrero negro
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | sarankhola
# Processing Record 50 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 4 | yumen
# Processing Record 2 of Set 4 | ilovlya
# Processing Record 3 of Set 4 | kiama
# Processing Record 4 of Set 4 | uzyn
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | bosaso
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | idlib
# Processing Record 10 of Set 4 | batamshinskiy
# Processing Record 11 of Set 4 | chumikan
# Processing Record 12 of Set 4 | venado tuerto
# Processing Record 13 of Set 4 | long xuyen
# Processing Record 14 of Set 4 | ryotsu
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | sinop
# Processing Record 17 of Set 4 | svetlyy
# Processing Record 18 of Set 4 | whitehorse
# Processing Record 19 of Set 4 | aripuana
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | araouane
# Processing Record 22 of Set 4 | opuwo
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | kalininsk
# Processing Record 26 of Set 4 | brandon
# Processing Record 27 of Set 4 | lata
# Processing Record 28 of Set 4 | vanavara
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | shizukuishi
# Processing Record 31 of Set 4 | asosa
# Processing Record 32 of Set 4 | caravelas
# Processing Record 33 of Set 4 | hilo
# Processing Record 34 of Set 4 | san patricio
# Processing Record 35 of Set 4 | teeli
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | grand gaube
# Processing Record 38 of Set 4 | pionerskiy
# Processing Record 39 of Set 4 | inhambane
# Processing Record 40 of Set 4 | dukat
# Processing Record 41 of Set 4 | sioux lookout
# Processing Record 42 of Set 4 | parrita
# Processing Record 43 of Set 4 | port hardy
# Processing Record 44 of Set 4 | hofn
# Processing Record 45 of Set 4 | sangmelima
# Processing Record 46 of Set 4 | flinders
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | kahului
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 50 of Set 4 | khandyga
# Processing Record 1 of Set 5 | manacor
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | cape canaveral
# Processing Record 4 of Set 5 | qostanay
# Processing Record 5 of Set 5 | tilichiki
# Processing Record 6 of Set 5 | zamora
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | graciano sanchez
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | catuday
# Processing Record 12 of Set 5 | athens
# Processing Record 13 of Set 5 | nalut
# Processing Record 14 of Set 5 | marsh harbour
# Processing Record 15 of Set 5 | kruisfontein
# Processing Record 16 of Set 5 | magadan
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | ust-ishim
# Processing Record 23 of Set 5 | nanortalik
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | haines junction
# Processing Record 26 of Set 5 | edson
# Processing Record 27 of Set 5 | remanso
# Processing Record 28 of Set 5 | zhigansk
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | portland
# Processing Record 31 of Set 5 | barrow
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | csongrad
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | sainte-maxime
# Processing Record 36 of Set 5 | shache
# Processing Record 37 of Set 5 | savonlinna
# Processing Record 38 of Set 5 | kralendijk
# Processing Record 39 of Set 5 | jinxiang
# Processing Record 40 of Set 5 | sala consilina
# Processing Record 41 of Set 5 | porbandar
# Processing Record 42 of Set 5 | la asuncion
# Processing Record 43 of Set 5 | itaituba
# Processing Record 44 of Set 5 | saint-joseph
# Processing Record 45 of Set 5 | rabo de peixe
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | kautokeino
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | sao filipe
# Processing Record 1 of Set 6 | umm kaddadah
# Processing Record 2 of Set 6 | nioro
# Processing Record 3 of Set 6 | baculin
# Processing Record 4 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 6 | nabire
# Processing Record 6 of Set 6 | lebu
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | henties bay
# Processing Record 9 of Set 6 | russell
# Processing Record 10 of Set 6 | carlisle
# Processing Record 11 of Set 6 | dhidhdhoo
# Processing Record 12 of Set 6 | salinopolis
# Processing Record 13 of Set 6 | bethel
# Processing Record 14 of Set 6 | farah
# Processing Record 15 of Set 6 | hoogstraten
# Processing Record 16 of Set 6 | sao miguel do araguaia
# Processing Record 17 of Set 6 | sembe
# Processing Record 18 of Set 6 | gaya
# Processing Record 19 of Set 6 | port moresby
# Processing Record 20 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | isla mujeres
# Processing Record 23 of Set 6 | kyshtovka
# Processing Record 24 of Set 6 | balkanabat
# Processing Record 25 of Set 6 | khash
# Processing Record 26 of Set 6 | jieshou
# Processing Record 27 of Set 6 | arraial do cabo
# Processing Record 28 of Set 6 | port hedland
# Processing Record 29 of Set 6 | avarua
# Processing Record 30 of Set 6 | oyama
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | saint anthony
# Processing Record 33 of Set 6 | ola
# Processing Record 34 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 6 | partizanskoye
# Processing Record 36 of Set 6 | batagay
# Processing Record 37 of Set 6 | vagur
# Processing Record 38 of Set 6 | cockburn town
# Processing Record 39 of Set 6 | east london
# Processing Record 40 of Set 6 | pacifica
# Processing Record 41 of Set 6 | korla
# Processing Record 42 of Set 6 | canto do buriti
# Processing Record 43 of Set 6 | kodinsk
# Processing Record 44 of Set 6 | nara
# Processing Record 45 of Set 6 | sursk
# Processing Record 46 of Set 6 | watsa
# Processing Record 47 of Set 6 | goderich
# Processing Record 48 of Set 6 | meulaboh
# Processing Record 49 of Set 6 | varhaug
# Processing Record 50 of Set 6 | tuktoyaktuk
# Processing Record 1 of Set 7 | orbetello
# Processing Record 2 of Set 7 | san andres
# Processing Record 3 of Set 7 | severo-yeniseyskiy
# Processing Record 4 of Set 7 | hot springs
# Processing Record 5 of Set 7 | isla vista
# Processing Record 6 of Set 7 | asfi
# Processing Record 7 of Set 7 | eisenerz
# Processing Record 8 of Set 7 | rock sound
# Processing Record 9 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 7 | krutinka
# Processing Record 11 of Set 7 | tripoli
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | angoche
# Processing Record 14 of Set 7 | naraini
# Processing Record 15 of Set 7 | abaete
# Processing Record 16 of Set 7 | roma
# Processing Record 17 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 18 of Set 7 | ottawa
# Processing Record 19 of Set 7 | pantai remis
# Processing Record 20 of Set 7 | makakilo city
# Processing Record 21 of Set 7 | polunochnoye
# Processing Record 22 of Set 7 | mahajanga
# Processing Record 23 of Set 7 | kalmunai
# Processing Record 24 of Set 7 | serik
# Processing Record 25 of Set 7 | ilebo
# Processing Record 26 of Set 7 | pietarsaari
# Processing Record 27 of Set 7 | visby
# Processing Record 28 of Set 7 | parakai
# Processing Record 29 of Set 7 | karratha
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | ballina
# Processing Record 32 of Set 7 | turka
# Processing Record 33 of Set 7 | mitsamiouli
# Processing Record 34 of Set 7 | raga
# Processing Record 35 of Set 7 | mananjary
# Processing Record 36 of Set 7 | hovd
# Processing Record 37 of Set 7 | port-gentil
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 7 | pangody
# Processing Record 41 of Set 7 | sorong
# Processing Record 42 of Set 7 | laibin
# Processing Record 43 of Set 7 | vrangel
# Processing Record 44 of Set 7 | dawson creek
# Processing Record 45 of Set 7 | jining
# Processing Record 46 of Set 7 | naze
# Processing Record 47 of Set 7 | ikom
# Processing Record 48 of Set 7 | vestmannaeyjar
# Processing Record 49 of Set 7 | geraldton
# Processing Record 50 of Set 7 | grindavik
# Processing Record 1 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 8 | ahuimanu
# Processing Record 3 of Set 8 | zyryanka
# Processing Record 4 of Set 8 | staraya toropa
# Processing Record 5 of Set 8 | tommot
# Processing Record 6 of Set 8 | ghatampur
# Processing Record 7 of Set 8 | sakakah
# Processing Record 8 of Set 8 | qujing
# Processing Record 9 of Set 8 | nouakchott
# Processing Record 10 of Set 8 | ikwiriri
# Processing Record 11 of Set 8 | clyde river
# Processing Record 12 of Set 8 | cherskiy
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | waitati
# Processing Record 15 of Set 8 | ushtobe
# Processing Record 16 of Set 8 | komsomolskiy
# Processing Record 17 of Set 8 | masalli
# Processing Record 18 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 8 | krasnogvardeyskiy
# Processing Record 20 of Set 8 | narsaq
# Processing Record 21 of Set 8 | rawson
# Processing Record 22 of Set 8 | tessalit
# Processing Record 23 of Set 8 | pingliang
# Processing Record 24 of Set 8 | sterling
# Processing Record 25 of Set 8 | phangnga
# Processing Record 26 of Set 8 | nova olimpia
# Processing Record 27 of Set 8 | severo-kurilsk
# Processing Record 28 of Set 8 | port elizabeth
# Processing Record 29 of Set 8 | lulea
# Processing Record 30 of Set 8 | abha
# Processing Record 31 of Set 8 | ulladulla
# Processing Record 32 of Set 8 | chicama
# Processing Record 33 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 8 | iqaluit
# Processing Record 35 of Set 8 | ulaangom
# Processing Record 36 of Set 8 | rocky mount
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | westlake village
# Processing Record 39 of Set 8 | irtyshskiy
# Processing Record 40 of Set 8 | chipinge
# Processing Record 41 of Set 8 | chapais
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | san carlos de bariloche
# Processing Record 44 of Set 8 | acarau
# Processing Record 45 of Set 8 | vila franca do campo
# Processing Record 46 of Set 8 | niort
# Processing Record 47 of Set 8 | kovdor
# Processing Record 48 of Set 8 | show low
# Processing Record 49 of Set 8 | promissao
# Processing Record 50 of Set 8 | albi
# Processing Record 1 of Set 9 | gat
# Processing Record 2 of Set 9 | santiago de cao
# Processing Record 3 of Set 9 | xuanzhou
# Processing Record 4 of Set 9 | hirakud
# Processing Record 5 of Set 9 | maumere
# Processing Record 6 of Set 9 | codrington
# Processing Record 7 of Set 9 | south venice
# Processing Record 8 of Set 9 | bahia honda
# Processing Record 9 of Set 9 | dharchula
# Processing Record 10 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 9 | sambava
# Processing Record 12 of Set 9 | dubbo
# Processing Record 13 of Set 9 | catalina foothills
# Processing Record 14 of Set 9 | talcahuano
# Processing Record 15 of Set 9 | taltal
# Processing Record 16 of Set 9 | ylojarvi
# Processing Record 17 of Set 9 | vostok
# Processing Record 18 of Set 9 | kathmandu
# Processing Record 19 of Set 9 | hwange
# Processing Record 20 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 21 of Set 9 | tinskoy
# Processing Record 22 of Set 9 | pyu
# Processing Record 23 of Set 9 | jiexiu
# Processing Record 24 of Set 9 | morant bay
# Processing Record 25 of Set 9 | mae sai
# Processing Record 26 of Set 9 | ponta do sol
# Processing Record 27 of Set 9 | nadvoitsy
# Processing Record 28 of Set 9 | noyabrsk
# Processing Record 29 of Set 9 | constitucion
# Processing Record 30 of Set 9 | saskylakh
# Processing Record 31 of Set 9 | goba
# Processing Record 32 of Set 9 | biala podlaska
# Processing Record 33 of Set 9 | teya
# Processing Record 34 of Set 9 | srandakan
# Processing Record 35 of Set 9 | itarema
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | whitianga
# Processing Record 39 of Set 9 | kurilsk
# Processing Record 40 of Set 9 | kitob
# Processing Record 41 of Set 9 | beringovskiy
# Processing Record 42 of Set 9 | naron
# Processing Record 43 of Set 9 | la union
# Processing Record 44 of Set 9 | carutapera
# Processing Record 45 of Set 9 | bolshoye soldatskoye
# City not found. Skipping...
# Processing Record 46 of Set 9 | trelew
# Processing Record 47 of Set 9 | fontem
# Processing Record 48 of Set 9 | gorontalo
# Processing Record 49 of Set 9 | lambari
# Processing Record 50 of Set 9 | manta
# Processing Record 1 of Set 10 | bereda
# Processing Record 2 of Set 10 | natchitoches
# Processing Record 3 of Set 10 | tazmalt
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | latehar
# Processing Record 6 of Set 10 | longyearbyen
# Processing Record 7 of Set 10 | delhi
# Processing Record 8 of Set 10 | nuuk
# Processing Record 9 of Set 10 | loveland
# Processing Record 10 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 10 | handan
# Processing Record 12 of Set 10 | trairi
# Processing Record 13 of Set 10 | dargaville
# Processing Record 14 of Set 10 | mutum
# Processing Record 15 of Set 10 | santa ines
# Processing Record 16 of Set 10 | loningen
# Processing Record 17 of Set 10 | zhangye
# Processing Record 18 of Set 10 | catamarca
# Processing Record 19 of Set 10 | kaliua
# Processing Record 20 of Set 10 | general roca
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 10 | graaff-reinet
# Processing Record 24 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 10 | gazojak
# Processing Record 26 of Set 10 | acapulco
# Processing Record 27 of Set 10 | necochea
# Processing Record 28 of Set 10 | roald
# Processing Record 29 of Set 10 | ca mau
# Processing Record 30 of Set 10 | ukiah
# Processing Record 31 of Set 10 | bilma
# Processing Record 32 of Set 10 | boende
# Processing Record 33 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 34 of Set 10 | navirai
# Processing Record 35 of Set 10 | kununurra
# Processing Record 36 of Set 10 | merke
# Processing Record 37 of Set 10 | coahuayana
# Processing Record 38 of Set 10 | shar
# Processing Record 39 of Set 10 | saurimo
# Processing Record 40 of Set 10 | candido mendes
# Processing Record 41 of Set 10 | arman
# Processing Record 42 of Set 10 | fairfield
# Processing Record 43 of Set 10 | chandur
# Processing Record 44 of Set 10 | port keats
# Processing Record 45 of Set 10 | caucaia
# Processing Record 46 of Set 10 | hobe sound
# Processing Record 47 of Set 10 | fukue
# Processing Record 48 of Set 10 | armeria
# Processing Record 49 of Set 10 | kolondieba
# Processing Record 50 of Set 10 | bereznik
# Processing Record 1 of Set 11 | faya
# Processing Record 2 of Set 11 | labuhan
# Processing Record 3 of Set 11 | tazovskiy
# Processing Record 4 of Set 11 | surt
# Processing Record 5 of Set 11 | flin flon
# Processing Record 6 of Set 11 | gilgit
# Processing Record 7 of Set 11 | cayenne
# Processing Record 8 of Set 11 | belen
# Processing Record 9 of Set 11 | belaya gora
# Processing Record 10 of Set 11 | hami
# Processing Record 11 of Set 11 | te karaka
# Processing Record 12 of Set 11 | black river
# Processing Record 13 of Set 11 | garm
# City not found. Skipping...
# Processing Record 14 of Set 11 | kamenskiy
# Processing Record 15 of Set 11 | mecca
# Processing Record 16 of Set 11 | idenao
# Processing Record 17 of Set 11 | durban
# Processing Record 18 of Set 11 | qaracala
# Processing Record 19 of Set 11 | aklavik
# Processing Record 20 of Set 11 | salinas
# Processing Record 21 of Set 11 | evensk
# Processing Record 22 of Set 11 | lopsmarka
# Processing Record 23 of Set 11 | rodby
# Processing Record 24 of Set 11 | vanimo
# Processing Record 25 of Set 11 | maxixe
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 11 | palu
# Processing Record 29 of Set 11 | tres arroyos
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | tezu
# Processing Record 32 of Set 11 | salym
# Processing Record 33 of Set 11 | klaksvik
# Processing Record 34 of Set 11 | mocuba
# Processing Record 35 of Set 11 | ploemeur
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | trincomalee
# Processing Record 40 of Set 11 | altay
# Processing Record 41 of Set 11 | waipawa
# Processing Record 42 of Set 11 | honningsvag
# Processing Record 43 of Set 11 | aksu
# Processing Record 44 of Set 11 | sao domingos
# Processing Record 45 of Set 11 | raton
# Processing Record 46 of Set 11 | padrauna
# Processing Record 47 of Set 11 | bathurst
# Processing Record 48 of Set 11 | redwater
# Processing Record 49 of Set 11 | namatanai
# Processing Record 50 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 12 | chicla
# Processing Record 2 of Set 12 | logstor
# Processing Record 3 of Set 12 | lagunas
# Processing Record 4 of Set 12 | kerema
# Processing Record 5 of Set 12 | tocopilla
# Processing Record 6 of Set 12 | noshiro
# Processing Record 7 of Set 12 | kyzyl-suu
# Processing Record 8 of Set 12 | mizdah
# Processing Record 9 of Set 12 | portoviejo
# Processing Record 10 of Set 12 | north bend
# Processing Record 11 of Set 12 | warangal
# Processing Record 12 of Set 12 | kysyl-syr
# Processing Record 13 of Set 12 | kletnya
# Processing Record 14 of Set 12 | kitovo
# Processing Record 15 of Set 12 | oktyabrskoye
# Processing Record 16 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 17 of Set 12 | manga
# Processing Record 18 of Set 12 | richards bay
# Processing Record 19 of Set 12 | delano
# Processing Record 20 of Set 12 | ketchikan
# Processing Record 21 of Set 12 | quatre cocos
# Processing Record 22 of Set 12 | mattru
# Processing Record 23 of Set 12 | pierre
# Processing Record 24 of Set 12 | chara
# Processing Record 25 of Set 12 | baft
# Processing Record 26 of Set 12 | jalu
# Processing Record 27 of Set 12 | qaqortoq
# Processing Record 28 of Set 12 | bongandanga
# Processing Record 29 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 30 of Set 12 | furth im wald
# Processing Record 31 of Set 12 | central point
# Processing Record 32 of Set 12 | copiapo
# Processing Record 33 of Set 12 | brae
# Processing Record 34 of Set 12 | yoichi
# Processing Record 35 of Set 12 | mao
# Processing Record 36 of Set 12 | ruteng
# Processing Record 37 of Set 12 | venice
# Processing Record 38 of Set 12 | maragogi
# Processing Record 39 of Set 12 | pulawy
# Processing Record 40 of Set 12 | alihe
# Processing Record 41 of Set 12 | borzna
# Processing Record 42 of Set 12 | ahipara
# Processing Record 43 of Set 12 | akola
# Processing Record 44 of Set 12 | burica
# City not found. Skipping...
# Processing Record 45 of Set 12 | jamkhed
# Processing Record 46 of Set 12 | pringsewu
# Processing Record 47 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 12 | samoded
# Processing Record 49 of Set 12 | turkistan
# Processing Record 50 of Set 12 | nerekhta
# Processing Record 1 of Set 13 | bandarbeyla
# Processing Record 2 of Set 13 | dakar
# Processing Record 3 of Set 13 | pochinki
# Processing Record 4 of Set 13 | almaznyy
# Processing Record 5 of Set 13 | oranjemund
# Processing Record 6 of Set 13 | abu samrah
# Processing Record 7 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 13 | iskateley
# Processing Record 9 of Set 13 | caluquembe
# Processing Record 10 of Set 13 | luderitz
# Processing Record 11 of Set 13 | les cayes
# Processing Record 12 of Set 13 | meiganga
# Processing Record 13 of Set 13 | santa helena de goias
# Processing Record 14 of Set 13 | cabedelo
# Processing Record 15 of Set 13 | canberra
# Processing Record 16 of Set 13 | batagay-alyta
# Processing Record 17 of Set 13 | loukisia
# Processing Record 18 of Set 13 | san jose
# Processing Record 19 of Set 13 | port macquarie
# Processing Record 20 of Set 13 | monrovia
# Processing Record 21 of Set 13 | pho chai
# Processing Record 22 of Set 13 | lasa
# Processing Record 23 of Set 13 | avezzano
# Processing Record 24 of Set 13 | kabelvag
# Processing Record 25 of Set 13 | kassala
# Processing Record 26 of Set 13 | udachnyy
# Processing Record 27 of Set 13 | tigil
# Processing Record 28 of Set 13 | sarangani
# Processing Record 29 of Set 13 | darhan
# Processing Record 30 of Set 13 | sayyan
# Processing Record 31 of Set 13 | homer
# Processing Record 32 of Set 13 | terra santa
# Processing Record 33 of Set 13 | taquaritinga
# Processing Record 34 of Set 13 | basoko
# Processing Record 35 of Set 13 | tigzirt
# Processing Record 36 of Set 13 | punta alta
# Processing Record 37 of Set 13 | college
# Processing Record 38 of Set 13 | springdale
# Processing Record 39 of Set 13 | eureka
# Processing Record 40 of Set 13 | alice springs
# Processing Record 41 of Set 13 | gohpur
# Processing Record 42 of Set 13 | potrerillos
# Processing Record 43 of Set 13 | petionville
# Processing Record 44 of Set 13 | sampit
# Processing Record 45 of Set 13 | helong
# Processing Record 46 of Set 13 | jocon
# Processing Record 47 of Set 13 | iralaya
# Processing Record 48 of Set 13 | duncan
# Processing Record 49 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 50 of Set 13 | high level
# Processing Record 1 of Set 14 | ucluelet
# Processing Record 2 of Set 14 | karasjok
# Processing Record 3 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 14 | biak
# Processing Record 5 of Set 14 | thohoyandou
# Processing Record 6 of Set 14 | mugur-aksy
# Processing Record 7 of Set 14 | price
# Processing Record 8 of Set 14 | rehoboth
# Processing Record 9 of Set 14 | shitkino
# Processing Record 10 of Set 14 | xuddur
# Processing Record 11 of Set 14 | prado
# Processing Record 12 of Set 14 | hailey
# Processing Record 13 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 14 | novi
# Processing Record 15 of Set 14 | ixtapa
# Processing Record 16 of Set 14 | belyy yar
# Processing Record 17 of Set 14 | pandamatenga
# Processing Record 18 of Set 14 | vero beach
# Processing Record 19 of Set 14 | kamena vourla
# Processing Record 20 of Set 14 | murdochville
# Processing Record 21 of Set 14 | kotlas
# Processing Record 22 of Set 14 | deputatskiy
# Processing Record 23 of Set 14 | greenwood
# Processing Record 24 of Set 14 | mehamn
# Processing Record 25 of Set 14 | karacabey
# Processing Record 26 of Set 14 | pedasi
# Processing Record 27 of Set 14 | benedita
# Processing Record 28 of Set 14 | chabahar
# Processing Record 29 of Set 14 | brufut
# Processing Record 30 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 14 | okakarara
# Processing Record 32 of Set 14 | bogande
# Processing Record 33 of Set 14 | swan hill
# Processing Record 34 of Set 14 | mount gambier
# Processing Record 35 of Set 14 | taganak
# Processing Record 36 of Set 14 | riyadh
# Processing Record 37 of Set 14 | mareeba
# Processing Record 38 of Set 14 | son la
# Processing Record 39 of Set 14 | ankazoabo
# Processing Record 40 of Set 14 | pombas
# Processing Record 41 of Set 14 | lujan
# Processing Record 42 of Set 14 | san vicente
# Processing Record 43 of Set 14 | tokur
# Processing Record 44 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 14 | oussouye
# Processing Record 46 of Set 14 | totness
# Processing Record 47 of Set 14 | pitimbu
# Processing Record 48 of Set 14 | maloy
# Processing Record 49 of Set 14 | aden
# Processing Record 50 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 15 | monte patria
# Processing Record 2 of Set 15 | uthal
# Processing Record 3 of Set 15 | katsuura
# Processing Record 4 of Set 15 | wajid
# Processing Record 5 of Set 15 | srimushnam
# Processing Record 6 of Set 15 | nisia floresta
# Processing Record 7 of Set 15 | kalmar
# Processing Record 8 of Set 15 | wewak
# Processing Record 9 of Set 15 | atar
# Processing Record 10 of Set 15 | bowen
# Processing Record 11 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 15 | hobyo
# Processing Record 13 of Set 15 | poum
# Processing Record 14 of Set 15 | hervey bay
# Processing Record 15 of Set 15 | massakory
# Processing Record 16 of Set 15 | changping
# Processing Record 17 of Set 15 | esna
# Processing Record 18 of Set 15 | batie
# Processing Record 19 of Set 15 | troitsko-pechorsk
# Processing Record 20 of Set 15 | marang
# Processing Record 21 of Set 15 | qibili
# City not found. Skipping...
# Processing Record 22 of Set 15 | kargasok
# Processing Record 23 of Set 15 | boa vista
# Processing Record 24 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 15 | kaohsiung
# Processing Record 26 of Set 15 | xichang
# Processing Record 27 of Set 15 | manokwari
# Processing Record 28 of Set 15 | astoria
# Processing Record 29 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 15 | luena
# Processing Record 31 of Set 15 | tungor
# Processing Record 32 of Set 15 | monte carmelo
# Processing Record 33 of Set 15 | bielefeld
# Processing Record 34 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 15 | lucapa
# Processing Record 36 of Set 15 | nantucket
# Processing Record 37 of Set 15 | turukhansk
# Processing Record 38 of Set 15 | dudinka
# Processing Record 39 of Set 15 | patamundai
# Processing Record 40 of Set 15 | canby
# Processing Record 41 of Set 15 | santo tomas
# Processing Record 42 of Set 15 | inirida
# Processing Record 43 of Set 15 | bartica
# Processing Record 44 of Set 15 | nanning
# Processing Record 45 of Set 15 | burnie
# Processing Record 46 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 47 of Set 15 | edgewater
# Processing Record 48 of Set 15 | vuktyl
# Processing Record 49 of Set 15 | vredendal
# Processing Record 50 of Set 15 | lokken verk
# City not found. Skipping...
# Processing Record 1 of Set 16 | sire
# Processing Record 2 of Set 16 | saint-pierre
# Processing Record 3 of Set 16 | thap than
# Processing Record 4 of Set 16 | umm lajj
# Processing Record 5 of Set 16 | cascais
# Processing Record 6 of Set 16 | wenling
# Processing Record 7 of Set 16 | jihlava
# Processing Record 8 of Set 16 | fasa
# Processing Record 9 of Set 16 | menemen
# Processing Record 10 of Set 16 | galle
# Processing Record 11 of Set 16 | geresk
# City not found. Skipping...
# Processing Record 12 of Set 16 | pagudpud
# Processing Record 13 of Set 16 | majalgaon
# Processing Record 14 of Set 16 | mongoumba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dunedin -45.8742  170.5036     50.81        92         100
# 1         Souillac -20.5167   57.5167     73.69        63           0
# 2           Beloha -25.1667   45.0500     79.45        63          19
# 3        Heinsberg  51.0667    6.0833     63.46        72          53
# 4      New Norfolk -42.7826  147.0587     47.91        67         100
# 5             Tonj   7.2737   28.6822     90.77        21         100
# 6      Kloulklubed   7.0419  134.2556     83.59        77          15
# 7  Plettenberg Bay -34.0527   23.3716     67.80        68          47
# 8            Lagoa  39.0500  -27.9833     60.69        70         100
# 9        Tuatapere -46.1333  167.6833     46.42        88          87
#
#    Wind Speed Country                 Date       Description
# 0        3.24      NZ  2022-11-12 14:07:54   overcast clouds
# 1        8.66      MU  2022-11-12 14:04:12         clear sky
# 2       20.56      MG  2022-11-12 14:05:32        few clouds
# 3        2.33      DE  2022-11-12 14:07:55     broken clouds
# 4        0.89      AU  2022-11-12 14:02:58   overcast clouds
# 5        1.72      SS  2022-11-12 14:07:55   overcast clouds
# 6       11.23      PW  2022-11-12 14:07:55        few clouds
# 7        8.48      ZA  2022-11-12 14:04:05  scattered clouds
# 8       24.29      PT  2022-11-12 13:58:52   overcast clouds
# 9        3.91      NZ  2022-11-12 14:02:55   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0      Dunedin      NZ  2022-11-12 14:07:54 -45.8742  170.5036     50.81
# 1     Souillac      MU  2022-11-12 14:04:12 -20.5167   57.5167     73.69
# 2       Beloha      MG  2022-11-12 14:05:32 -25.1667   45.0500     79.45
# 3    Heinsberg      DE  2022-11-12 14:07:55  51.0667    6.0833     63.46
# 4  New Norfolk      AU  2022-11-12 14:02:58 -42.7826  147.0587     47.91
#
#    Humidity  Cloudiness  Wind Speed      Description
# 0        92         100        3.24  overcast clouds
# 1        63           0        8.66        clear sky
# 2        63          19       20.56       few clouds
# 3        72          53        2.33    broken clouds
# 4        67         100        0.89  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Date            object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
